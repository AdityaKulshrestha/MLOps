# %%
import pandas as pd
from datetime import datetime

# entity_df generally comes from upstream systems
entity_df = pd.DataFrame.from_dict({
    "token": ["btc","btc","btc","btc"],
    "event_date": [
        datetime(2021, 4, 12, 10, 59, 42),
        datetime(2021, 4, 12, 8,  12, 10),
        datetime(2021, 4, 12, 16, 40, 26),
        datetime(2021, 4, 12, 15, 1 , 12)
    ]
})

entity_df.head()
# Out:
#   token          event_date
# 0   btc 2021-04-12 10:59:42
# 1   btc 2021-04-12 08:12:10
# 2   btc 2021-04-12 16:40:26
# 3   btc 2021-04-12 15:01:12

# %%
# !pip install feast
# Out:
# Collecting feast
#   Downloading feast-0.39.0-py2.py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 1.9 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: pygments<3,>=2.12.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (2.18.0)
# Collecting toml<1,>=0.10.0
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (8.1.7)
# Requirement already satisfied: pandas<3,>=1.4.3 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (2.1.4)
# Collecting typeguard>=4.0.0
#   Downloading typeguard-4.3.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: protobuf<5.0.0,>=4.24.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (4.25.3)
# Requirement already satisfied: SQLAlchemy[mypy]>1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (2.0.31)
# Requirement already satisfied: pydantic>=2.0.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (2.7.4)
# Requirement already satisfied: colorama<1,>=0.3.9 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (0.4.6)
# Requirement already satisfied: jsonschema in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (4.22.0)
# Requirement already satisfied: tenacity<9,>=7 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (8.4.2)
# Collecting mypy-protobuf>=3.1
#   Downloading mypy_protobuf-3.6.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: PyYAML<7,>=5.4.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (6.0.1)
# Collecting dill~=0.3.0
#   Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Requirement already satisfied: numpy<2,>=1.22 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (1.26.4)
# Collecting mmh3
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 KB 262.4 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tabulate<1,>=0.8.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (0.9.0)
# Requirement already satisfied: requests in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (2.32.3)
# Requirement already satisfied: Jinja2<4,>=2 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (3.1.4)
# Requirement already satisfied: fastapi>=0.68.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (0.111.0)
# Collecting dask[dataframe]>=2024.4.2
#   Downloading dask-2024.6.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: uvicorn[standard]<1,>=0.14.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (0.30.1)
# Requirement already satisfied: gunicorn in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (22.0.0)
# Requirement already satisfied: tqdm<5,>=4 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (4.66.4)
# Requirement already satisfied: pyarrow>=4 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from feast) (15.0.2)
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from dask[dataframe]>=2024.4.2->feast) (3.0.0)
# Collecting toolz>=0.10.0
#   Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Collecting partd>=1.2.0
#   Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from dask[dataframe]>=2024.4.2->feast) (2024.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from dask[dataframe]>=2024.4.2->feast) (24.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from dask[dataframe]>=2024.4.2->feast) (7.1.0)
# Collecting dask-expr<1.2,>=1.1
#   Downloading dask_expr-1.1.6-py3-none-any.whl (206 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.6/206.6 KB 916.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (5.10.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (4.12.2)
# Requirement already satisfied: python-multipart>=0.0.7 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (0.0.9)
# Requirement already satisfied: orjson>=3.2.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (3.10.5)
# Requirement already satisfied: email_validator>=2.0.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (2.1.2)
# Requirement already satisfied: httpx>=0.23.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (0.27.0)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (0.0.4)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi>=0.68.0->feast) (0.37.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from Jinja2<4,>=2->feast) (2.1.5)
# Collecting types-protobuf>=4.24
#   Downloading types_protobuf-5.26.0.20240422-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 KB 263.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from pandas<3,>=1.4.3->feast) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from pandas<3,>=1.4.3->feast) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from pandas<3,>=1.4.3->feast) (2024.1)
# Requirement already satisfied: pydantic-core==2.18.4 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from pydantic>=2.0.0->feast) (2.18.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from pydantic>=2.0.0->feast) (0.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from SQLAlchemy[mypy]>1->feast) (3.0.3)
# Collecting mypy>=0.910
#   Downloading mypy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 4.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: h11>=0.8 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.14.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.22.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.19.0)
# Requirement already satisfied: websockets>=10.4 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (12.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from uvicorn[standard]<1,>=0.14.0->feast) (0.6.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from jsonschema->feast) (23.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from jsonschema->feast) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from jsonschema->feast) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from jsonschema->feast) (0.18.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from requests->feast) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from requests->feast) (2024.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from requests->feast) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from requests->feast) (2.2.2)
# Requirement already satisfied: dnspython>=2.0.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from email_validator>=2.0.0->fastapi>=0.68.0->feast) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from fastapi-cli>=0.0.2->fastapi>=0.68.0->feast) (0.12.3)
# Requirement already satisfied: httpcore==1.* in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi>=0.68.0->feast) (1.0.5)
# Requirement already satisfied: anyio in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi>=0.68.0->feast) (4.4.0)
# Requirement already satisfied: sniffio in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from httpx>=0.23.0->fastapi>=0.68.0->feast) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2024.4.2->feast) (3.19.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from mypy>=0.910->SQLAlchemy[mypy]>1->feast) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from mypy>=0.910->SQLAlchemy[mypy]>1->feast) (2.0.1)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: six>=1.5 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.3->feast) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from anyio->httpx>=0.23.0->fastapi>=0.68.0->feast) (1.2.1)
# Requirement already satisfied: rich>=10.11.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi>=0.68.0->feast) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi>=0.68.0->feast) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi>=0.68.0->feast) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/akarx/MLOps/mlops_venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi>=0.68.0->feast) (0.1.2)
# Installing collected packages: mmh3, types-protobuf, typeguard, toolz, toml, mypy, locket, dill, partd, mypy-protobuf, dask, dask-expr, feast
# Successfully installed dask-2024.6.2 dask-expr-1.1.6 dill-0.3.8 feast-0.39.0 locket-1.0.0 mmh3-4.1.0 mypy-1.10.1 mypy-protobuf-3.6.0 partd-1.4.2 toml-0.10.2 toolz-0.12.1 typeguard-4.3.0 types-protobuf-5.26.0.20240422

# %%
from feast import FeatureStore

store = FeatureStore(repo_path=".")

training_df = store.get_historical_features(
    entity_df=entity_df, 
    feature_refs = [
        'token_hourly_features:prev_3days',
        'token_hourly_features:prev_4days',
        'token_hourly_features:prev_5days'        
    ],
).to_df()

training_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from feast import FeatureStore
# ----> 3 store = FeatureStore(repo_path=".")
#       5 training_df = store.get_historical_features(
#       6     entity_df=entity_df,
#       7     feature_refs = [
#    (...)
#      11     ],
#      12 ).to_df()
#      14 training_df.head()
#
# File ~/MLOps/mlops_venv/lib/python3.10/site-packages/feast/feature_store.py:143, in FeatureStore.__init__(self, repo_path, config, fs_yaml_file)
#     141     self.config = load_repo_config(self.repo_path, fs_yaml_file)
#     142 else:
# --> 143     self.config = load_repo_config(
#     144         self.repo_path, utils.get_default_yaml_file_path(self.repo_path)
#     145     )
#     147 registry_config = self.config.registry
#     148 if registry_config.registry_type == "sql":
#
# File ~/MLOps/mlops_venv/lib/python3.10/site-packages/feast/repo_config.py:542, in load_repo_config(repo_path, fs_yaml_file)
#     539 def load_repo_config(repo_path: Path, fs_yaml_file: Path) -> RepoConfig:
#     540     config_path = fs_yaml_file
# --> 542     with open(config_path) as f:
#     543         raw_config = yaml.safe_load(os.path.expandvars(f.read()))
#     544         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'feature_store.yaml'
